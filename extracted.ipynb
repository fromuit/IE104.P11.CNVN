# %%
import os
from bs4 import BeautifulSoup

def extract_specific_content(html_content):
    # Parse HTML
    soup = BeautifulSoup(html_content, 'html.parser')
    
    # Tạo soup mới để chứa kết quả
    new_soup = BeautifulSoup('', 'html.parser')
    
    # Lấy 2 dòng đầu tiên từ DOCTYPE và html tag
    doctype = '<!DOCTYPE html>\n'
    html_tag = '<html lang="vi">\n'
    
    # Lấy thẻ meta charset từ head
    meta_charset = soup.find('meta', attrs={'charset': 'utf-8'})
    
    # Lấy các div cụ thể từ body
    title_top = soup.find('div', class_='title-top')
    chapter_content = soup.find('div', id='chapter-content', class_='long-text no-select')
    
    # Tạo cấu trúc HTML mới
    result = f"""{doctype}{html_tag}
<head>
    {str(meta_charset) if meta_charset else ''}
</head>
<body>
    {str(title_top) if title_top else ''}
    {str(chapter_content) if chapter_content else ''}
</body>
</html>"""
    
    return result

def process_directory(input_dir):
    # Tạo thư mục output với tên input_dir + 'new'
    output_dir = "1" + input_dir 
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    
    # Xử lý từng file HTML trong thư mục input
    for filename in os.listdir(input_dir):
        if filename.endswith('.html'):
            input_path = os.path.join(input_dir, filename)
            output_path = os.path.join(output_dir, filename)
            
            # Đọc file HTML
            with open(input_path, 'r', encoding='utf-8') as f:
                html_content = f.read()
            
            # Xử lý và lấy nội dung cần thiết
            extracted_content = extract_specific_content(html_content)
            
            # Lưu kết quả vào file mới
            with open(output_path, 'w', encoding='utf-8') as f:
                f.write(extracted_content)
            
            print(f"Đã xử lý file: {filename}")

# Sử dụng hàm với thư mục input
input_directory = "seirei tsukai no blade dance"  # Thay đổi tên thư mục theo nhu cầu
process_directory(input_directory)
# Out:
# Đã xử lý file: c1-chuong-1-nguoi-la-tinh-linh-cua-ta.html
# Đã xử lý file: c10-phan-ket.html
# Đã xử lý file: c100-chuong-5-vu-khi-tinh-linh.html
# Đã xử lý file: c101-chuong-6-scarlet-valkyrie.html
# Đã xử lý file: c102-chuong-7-cross-fire.html
# Đã xử lý file: c103-ket.html
# Đã xử lý file: c104-chuong-10.html
# Đã xử lý file: c105-mo-dau.html
# Đã xử lý file: c106-chuong-1-muir-alenstarl.html
# Đã xử lý file: c107-chuong-2-tieng-goi-cua-bong-toi.html
# Đã xử lý file: c108-chuong-3-claire-bi-bat.html
# Đã xử lý file: c109-chuong-4-iseria-seaward.html
# Đã xử lý file: c11-loi-bat.html
# Đã xử lý file: c110-chuong-5-bi-mat-cua-scarlet.html
# Đã xử lý file: c111-chuong-6-lost-cathedral.html
# Đã xử lý file: c112-chuong-7-kiem-vu-cua-long-cong-chua.html
# Đã xử lý file: c11229-mo-dau.html
# Đã xử lý file: c11230-chuong-1-hoang-hon-o-kinh-do.html
# Đã xử lý file: c11231-chuong-2-bua-tiec-o-vinh-dong.html
# Đã xử lý file: c11232-chuong-3-khoang-cach-hai-chi-em.html
# Đã xử lý file: c11233-chuong-4-long-vuong-cua-dracunia.html
# Đã xử lý file: c11234-chuong-5-den-hac-long.html
# Đã xử lý file: c11235-chuong-6-leonora-cam-do.html
# Đã xử lý file: c11236-chuong-7-chan-dang-long-vuong.html
# Đã xử lý file: c11237-chuong-8-nui-xac-va-song-mau.html
# Đã xử lý file: c11238-chuong-9-chan-thuc-quan-kiem.html
# Đã xử lý file: c11239-loi-bat.html
# Đã xử lý file: c113-chuong-8-laevateinn.html
# Đã xử lý file: c114-chuong-9-ma-vuong-thuc-tinh.html
# Đã xử lý file: c115-mo-dau.html
# Đã xử lý file: c116-chuong-1-tinh-linh-co-tai-hoa.html
# Đã xử lý file: c117-chuong-2-vu-dieu-cua-song-kiem.html
# Đã xử lý file: c118-chuong-3-cuoc-thi-tinh-linh-kiem-vu-be-mac.html
# Đã xử lý file: c119-chuong-4-su-that-ba-nam-truoc.html
# Đã xử lý file: c12-minh-hoa.html
# Đã xử lý file: c120-chuong-5-quyet-tam-cua-rinslet.html
# Đã xử lý file: c121-chuong-6-tro-lai-thanh-pho-bo-hoang.html
# Đã xử lý file: c122-chuong-7-nghi-thuc-giai-phong-an.html
# Đã xử lý file: c123-chuong-8-tinh-linh-vuong-duoc-giai-phong.html
# Đã xử lý file: c124-chuong-9-dem-cuoi.html
# Đã xử lý file: c125-ket.html
# Đã xử lý file: c126-mo-dau.html
# Đã xử lý file: c127-chuong-1-danh-mat-ky-uc.html
# Đã xử lý file: c128-chuong-2-tron-chay.html
# Đã xử lý file: c129-chuong-3-giao-quoc-rung-chuyen.html
# Đã xử lý file: c13-mo-dau.html
# Đã xử lý file: c130-chuong-4-mat-that-cua-ma-vuong.html
# Đã xử lý file: c131-chuong-5-ke-xam-pham.html
# Đã xử lý file: c132-chuong-6-muoi-hai-tinh-linh-ky-si.html
# Đã xử lý file: c133-chuong-7-dem-truoc-dai-le.html
# Đã xử lý file: c134-chuong-8-dai-le-tinh-linh.html
# Đã xử lý file: c135-chuong-9-hoc-vien-bi-tan-cong.html
# Đã xử lý file: c136-chuong-10-giai-phong-phong-an-kiem.html
# Đã xử lý file: c137-ket.html
# Đã xử lý file: c138-bat.html
# Đã xử lý file: c139-mo-dau.html
# Đã xử lý file: c14-chuong-1-thi-dau-doi-nhom.html
# Đã xử lý file: c140-chuong-1-thieu-nu-thuc-tinh.html
# Đã xử lý file: c141-chuong-2-di-san-cua-quy-vuong.html
# Đã xử lý file: c142-chuong-3-doi-hoa-nguc-hoi-sinh.html
# Đã xử lý file: c143-chuong-4-thanh-pho-bang-suong.html
# Đã xử lý file: c144-chuong-5-quai-vat-rang-nui-kyria.html
# Đã xử lý file: c145-chuong-6-lau-dai-vinh-dong.html
# Đã xử lý file: c146-chuong-7-ba-bang-vuong-zirnitra.html
# Đã xử lý file: c147-chuong-8-bang-hoa-nu-vuong.html
# Đã xử lý file: c148-ket.html
# Đã xử lý file: c149-mo-dau.html
# Đã xử lý file: c15-chuong-2-gio-nghi-trua-cua-cac-tieu-thu.html
# Đã xử lý file: c150-chuong-1-buoi-sang-o-vinh-mua-dong.html
# Đã xử lý file: c15032-minh-hoa.html
# Đã xử lý file: c15033-mo-dau.html
# Đã xử lý file: c15034-chuong-1-ki-uc-bi-phong-an.html
# Đã xử lý file: c15061-minh-hoa.html
# Đã xử lý file: c15062-minh-hoa.html
# Đã xử lý file: c151-chuong-2-thieu-nu-thuc-tinh.html
# Đã xử lý file: c152-chuong-3-ban-tay-ma-quai-cua-mot-am-muu.html
# Đã xử lý file: c15295-chuong-2-bong-toi-cua-zohar.html
# Đã xử lý file: c153-chuong-4-tro-lai-hoc-vien.html
# Đã xử lý file: c154-chuong-5-phao-dai-tram-mac.html
# Đã xử lý file: c155-chuong-6-revenant.html
# Đã xử lý file: c156-chuong-7-tinh-linh-co-cua-ma-vuong.html
# Đã xử lý file: c157-chuong-8-dot-nhap-de-do.html
# Đã xử lý file: c158-chuong-9-thap-nghien-cuu-guas-gibai.html
# Đã xử lý file: c159-chuong-10-bong-toi-thuc-tinh.html
# Đã xử lý file: c16-chuong-3-tinh-linh-co-that-the.html
# Đã xử lý file: c160-phan-ket.html
# Đã xử lý file: c16092-chuong-3-tai-hop.html
# Đã xử lý file: c161-loi-bat.html
# Đã xử lý file: c17-chuong-4-meo-con-loan-da.html
# Đã xử lý file: c17075-chuong-4-vien-du-sa-mac.html
# Đã xử lý file: c17076-chuong-5-nam-dam-quy.html
# Đã xử lý file: c17077-chuong-6-ke-gia-mao-quy-vuong.html
# Đã xử lý file: c18-chuong-5-ke-ke-tuc-ma-vuong.html
# Đã xử lý file: c18250-chuong-7-quy-vuong-phuc-sinh.html
# Đã xử lý file: c19-chuong-6-buoi-sang-xuat-hanh.html
# Đã xử lý file: c19748-chuong-8-xich-diem-tinh-linh-co.html
# Đã xử lý file: c2-chuong-2-hoc-vien-tinh-linh-areishia.html
# Đã xử lý file: c20-chuong-7-tran-chien-tai-khu-mo-cu.html
# Đã xử lý file: c20242-chuong-9-leviathan.html
# Đã xử lý file: c21-chuong-8-loi-thu-nhan-cua-fianna.html
# Đã xử lý file: c21305-chuong-10-quy-vuong-do.html
# Đã xử lý file: c22-chuong-9-doi-scarlet.html
# Đã xử lý file: c22575-chuong-11-hon-ma-bong-que-o-quy-do.html
# Đã xử lý file: c22822-chuong-12-tuyet-kiem-chien-than.html
# Đã xử lý file: c22823-phan-ket.html
# Đã xử lý file: c22824-loi-bat.html
# Đã xử lý file: c23-phan-ket.html
# Đã xử lý file: c24-loi-bat.html
# Đã xử lý file: c25-minh-hoa.html
# Đã xử lý file: c26-mo-dau.html
# Đã xử lý file: c27-chuong-1-cac-tieu-thu-day-som.html
# Đã xử lý file: c28-chuong-2-buoc-dot-pha-cua-doi-scarlet.html
# Đã xử lý file: c28798-chuong-7-elemental-festa.html
# Đã xử lý file: c28996-minh-hoa.html
# Đã xử lý file: c29-chuong-3-sinh-nhat-cua-claire.html
# Đã xử lý file: c29032-minh-hoa.html
# Đã xử lý file: c3-minh-hoa.html
# Đã xử lý file: c30-chuong-4-thanh-y-cua-mot-ki-si.html
# Đã xử lý file: c30325-chuong-1-dai-hoi-tinh-linh-o-de-do.html
# Đã xử lý file: c30339-mo-dau.html
# Đã xử lý file: c30569-minh-hoa.html
# Đã xử lý file: c30570-minh-hoa.html
# Đã xử lý file: c30571-minh-hoa.html
# Đã xử lý file: c30572-minh-hoa.html
# Đã xử lý file: c30573-minh-hoa.html
# Đã xử lý file: c30574-minh-hoa.html
# Đã xử lý file: c30575-minh-hoa.html
# Đã xử lý file: c30613-minh-hoa.html
# Đã xử lý file: c30614-minh-hoa.html
# Đã xử lý file: c30619-minh-hoa.html
# Đã xử lý file: c31-chuong-5-cac-ki-si-sylphid.html
# Đã xử lý file: c31448-chuong-1-giac-mo-cua-est.html
# Đã xử lý file: c32-chuong-6-bao-ve-hoc-vien-do-thi.html
# Đã xử lý file: c32382-minh-hoa.html
# Đã xử lý file: c33-chuong-7-thanh-le-valentia.html
# Đã xử lý file: c34-chuong-8-quyet-tam-cua-ellis.html
# Đã xử lý file: c35-chuong-9-tinh-linh-su-manh-nhat.html
# Đã xử lý file: c35595-chuong-2-nang-cong-chua-mat-tich.html
# Đã xử lý file: c36-phan-ket.html
# Đã xử lý file: c36395-chuong-11.html
# Đã xử lý file: c36396-loi-bat.html
# Đã xử lý file: c36399-loi-bat.html
# Đã xử lý file: c36405-loi-bat.html
# Đã xử lý file: c37-mo-dau.html
# Đã xử lý file: c37408-chuong-3-sa-mac-hong-tu-ghul-a-val.html
# Đã xử lý file: c38-chuong-1-chuan-bi-len-duong.html
# Đã xử lý file: c38487-minh-hoa.html
# Đã xử lý file: c38493-chuong-06.html
# Đã xử lý file: c39-chuong-2-chuyen-du-hanh-tren-khong.html
# Đã xử lý file: c4-chuong-3-ban-hoc-deu-la-cac-tieu-thu.html
# Đã xử lý file: c40-chuong-3-cong-chua-rong-dracunia.html
# Đã xử lý file: c40829-chuong-5-quy-vuong-do.html
# Đã xử lý file: c40830-chuong-6-lai-buon-bi-an.html
# Đã xử lý file: c41-chuong-4-hon-dao-phieu-du.html
# Đã xử lý file: c42-chuong-5-nghich-nuoc.html
# Đã xử lý file: c43-chuong-6-ran-nut.html
# Đã xử lý file: c43992-chuong-7-lang-mo-quy-vuong.html
# Đã xử lý file: c44-chuong-7-nu-tinh-linh-bong-dem.html
# Đã xử lý file: c44022-chuong-8-nu-de-cua-quy-vuong-thanh.html
# Đã xử lý file: c44060-chuong-9-lurie-lizaldia.html
# Đã xử lý file: c44491-chuong-10-hai-kiem-vu-su.html
# Đã xử lý file: c44492-phan-ket.html
# Đã xử lý file: c44493-loi-bat.html
# Đã xử lý file: c45-chuong-8-vu-hoi.html
# Đã xử lý file: c46-chuong-9-khac-an-bong-toi.html
# Đã xử lý file: c46117-minh-hoa.html
# Đã xử lý file: c47-chuong-10-tran-thu-hung-trong-qua-khu.html
# Đã xử lý file: c48-ket.html
# Đã xử lý file: c48306-mo-dau.html
# Đã xử lý file: c48307-chuong-1-ma-vuong.html
# Đã xử lý file: c48308-chuong-2-thanh-nu.html
# Đã xử lý file: c48309-chuong-3-nu-vuong-tro-ve.html
# Đã xử lý file: c48310-chuong-4-thuy-tinh-linh-co.html
# Đã xử lý file: c48311-chuong-5-tiec-an-mung.html
# Đã xử lý file: c48312-chuong-6-chiem-lai-de-do.html
# Đã xử lý file: c48313-chuong-7-phan-hoi-hoc-vien.html
# Đã xử lý file: c48314-chuong-8-coi-quy-hang-lam.html
# Đã xử lý file: c48315-chuong-9-cong-thu-chien-o-hoc-vien.html
# Đã xử lý file: c48316-chuong-10-astral-shift-linh-gioi-sap-nhap.html
# Đã xử lý file: c48321-chuong-11-thien-than-di-gioi.html
# Đã xử lý file: c48322-phan-ket.html
# Đã xử lý file: c48323-loi-bat.html
# Đã xử lý file: c48769-mo-dau.html
# Đã xử lý file: c48770-chuong-03.html
# Đã xử lý file: c49-mo-dau.html
# Đã xử lý file: c5-chuong-4-soi-meo-va-ky-si.html
# Đã xử lý file: c50-chuong-1-thanh-kiem-bi-gay-khuc.html
# Đã xử lý file: c50128-chuong-2-su-that-24-nam-ve-truoc.html
# Đã xử lý file: c50129-chuong-3-thanh-vuong.html
# Đã xử lý file: c51-chuong-2-cuoc-hen-3-nguoi.html
# Đã xử lý file: c51669-chuong-4-toi-de-do.html
# Đã xử lý file: c51670-chuong-5-quyet-tam-cua-rubia.html
# Đã xử lý file: c51671-chuong-6-thanh-do-bien-mat.html
# Đã xử lý file: c51672-chuong-7-liet-diem-ty-muoi.html
# Đã xử lý file: c51674-chuong-8-tien-ve-linh-gioi.html
# Đã xử lý file: c51675-chuong-9-toi-te-dan-kiem-vu.html
# Đã xử lý file: c51676-chuong-10-trieu-hoi-ma-vuong.html
# Đã xử lý file: c51678-chuong-11-terminus-est.html
# Đã xử lý file: c51679-phan-ket.html
# Đã xử lý file: c51685-loi-bat.html
# Đã xử lý file: c52-chuong-3-su-me-hoac-cua-cong-chua-rong.html
# Đã xử lý file: c53-chuong-4-chi-em-nha-laurenfrost.html
# Đã xử lý file: c54-chuong-5-tinh-linh-co-o-dai-than-dien.html
# Đã xử lý file: c55-chuong-6-ky-uc-cua-thanh-kiem.html
# Đã xử lý file: c56-chuong-7-tran-chien-that-su-bat-dau.html
# Đã xử lý file: c57-chuong-8-su-cam-do-cua-dem-toi.html
# Đã xử lý file: c57301-mo-dau.html
# Đã xử lý file: c57302-chuong-1-am-tinh-linh-vuong.html
# Đã xử lý file: c57303-chuong-2-gio-phan-cong.html
# Đã xử lý file: c57304-chuong-3-dieu-than-lac-hac-am-cua-quy-vuong.html
# Đã xử lý file: c57305-chuong-4-hoi-tu.html
# Đã xử lý file: c58-chuong-9-demon-slayer.html
# Đã xử lý file: c59-phan-ket.html
# Đã xử lý file: c59098-chuong-2-est-cham-soc-nguoi-om.html
# Đã xử lý file: c59099-chuong-3-viec-lam-them-tham-kin-cua-cong-chua.html
# Đã xử lý file: c6-chuong-5-tam-y-cua-claire.html
# Đã xử lý file: c60-loi-bat.html
# Đã xử lý file: c60438-chuong-5-cuoc-hon-chien-tren-khong.html
# Đã xử lý file: c61-mo-dau.html
# Đã xử lý file: c61605-chuong-4-san-lung-tinh-linh-nguc-no-huyen-thoai.html
# Đã xử lý file: c61607-chuong-5-cuoc-chien-noi-lau-than-bi-kinh-khung.html
# Đã xử lý file: c61608-chuong-6-tinh-linh-su-nghi-ngoi.html
# Đã xử lý file: c61611-loi-bat.html
# Đã xử lý file: c62-chuong-1-binh-minh-dau-tien.html
# Đã xử lý file: c62566-chuong-6-tran-quyet-chien-o-thanh-do.html
# Đã xử lý file: c63-chuong-2-su-gia-tu-cong-quoc-rossvale.html
# Đã xử lý file: c64-chuong-3-nepenthes-lore.html
# Đã xử lý file: c64774-chuong-7-hai-thanh-thanh-kiem.html
# Đã xử lý file: c65-chuong-4-milla-bassett.html
# Đã xử lý file: c65479-chuong-8-loi-cau-nguyen-cua-cac-tinh-linh-co.html
# Đã xử lý file: c66-chuong-5-buoi-toi-cua-moi-nguoi.html
# Đã xử lý file: c67-chuong-6-tran-dot-kich-giua-dem.html
# Đã xử lý file: c67101-chuong-9-true-force.html
# Đã xử lý file: c67999-chuong-cuoi-tro-lai-hoc-vien.html
# Đã xử lý file: c68-chuong-7-tro-lai.html
# Đã xử lý file: c68000-phan-ket.html
# Đã xử lý file: c68001-loi-bat.html
# Đã xử lý file: c68002-chuong-15.html
# Đã xử lý file: c69-chuong-8-ma-kiem-tai-sinh.html
# Đã xử lý file: c7-chuong-6-kiem-vu-giua-dem.html
# Đã xử lý file: c70-chuong-9-quyet-chien.html
# Đã xử lý file: c71-phan-ket.html
# Đã xử lý file: c72-loi-bat.html
# Đã xử lý file: c73-mo-dau.html
# Đã xử lý file: c74-chuong-1-thu-tuyen-chien.html
# Đã xử lý file: c75-chuong-2-claire-nghi-ngo.html
# Đã xử lý file: c76-chuong-3-bai-van-dap-cua-ellis.html
# Đã xử lý file: c77-chuong-4-mang-xa-dang-den-gan.html
# Đã xử lý file: c78-chuong-5-doi-tu-linh.html
# Đã xử lý file: c79-chuong-6-cong-chua-bi-bat-coc.html
# Đã xử lý file: c8-chuong-7-kiem-tinh-linh-est.html
# Đã xử lý file: c80-chuong-7-muu-luoc-cua-mu-phu-thuy.html
# Đã xử lý file: c81-chuong-8-cuoc-cham-tran-nay-lua.html
# Đã xử lý file: c82-chuong-9-pandemonium-van-ma-dien.html
# Đã xử lý file: c83-chuong-10-vu-co-manh-nhat.html
# Đã xử lý file: c84-phan-ket.html
# Đã xử lý file: c85-loi-bat.html
# Đã xử lý file: c86-mo-dau.html
# Đã xử lý file: c87-chuong-1-tiec-mung-thang-loi.html
# Đã xử lý file: c88-chuong-2-phu-thuy-va-thich-khach.html
# Đã xử lý file: c89-chuyen-tiep-phu-thuy-hoang-hon.html
# Đã xử lý file: c9-chuong-8-vu-co-manh-nhat.html
# Đã xử lý file: c90-chuong-3-bang-ma-va-hoa-mieu.html
# Đã xử lý file: c91-chuong-4-cuoc-hen-voi-rong.html
# Đã xử lý file: c92-chuyen-tiep-doi-inferno.html
# Đã xử lý file: c93-chuong-5-dem-truoc-tran-chung-ket.html
# Đã xử lý file: c94-ket.html
# Đã xử lý file: c95-mo-dau.html
# Đã xử lý file: c96-chuong-1-nguyen-vong-duoc-pho-thac.html
# Đã xử lý file: c97-chuong-2-kiem-vu-trong-dem.html
# Đã xử lý file: c98-chuong-3-chien-truong-toe-lua.html
# Đã xử lý file: c99-chuong-4-ma-kiem-bong-dem.html
