# %%
import pandas as pd

df = pd.read_excel(r'D:\UIT\Năm 3\OLAP\Dataset_backup\hako-main\hako_dataset_scrape.xlsx')
df
# Out:
#        ID                                             Tựa đề  \
# 0       1                       Seirei Tsukai no Blade Dance
# 1      10                    Utsuro no Hako to Zero no Maria
# 2     100                                        Accel World
# 3   10001  Watashi ga Koibito ni Nareru Wake Najian Muri ...
# 4   10002                  Wortenia senki - Cổng Light Novel
# ..    ...                                                ...
# 95  10280              Trọng Sinh Vào Một Tên Quý Tộc Ốm Yếu
# 96  10281  Bởi vì thời gian có hạn, cô ấy trở thành con d...
# 97  10284        Để giúp Anh Hiểu Tôi Hơn - Cổng Light Novel
# 98  10285  Nhật ký quan sát của tôi về Elena Evoy - Cổng ...
# 99  10286  The Demon Prince goes to the Academy - Cổng Li...
#
#                                             Link hako Phương thức dịch  \
# 0   https://ln.hako.vn/truyen/1-seirei-tsukai-no-b...      Truyện dịch
# 1   https://ln.hako.vn/truyen/10-utsuro-no-hako-to...      Truyện dịch
# ...
